# %%
import time
import json
from src.homepage2vec.model import Webpage

from src.homepage2vec.model import WebsiteClassifier


model = WebsiteClassifier()


with open("input_all_html.json", 'r') as file:
    data = json.load(file)

    time_start_single = time.time()
    for item in data:
        website = Webpage(item["url"])
        website.html = item["html"]

        if website.html != None:
            scores, embeddings = model.predict(website)

    time_end_single = time.time()

print("Delta single: " + str(time_end_single-time_start_single))
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Cell In[3], line 20
#      16         website = Webpage(item["url"])
#      17         website.html = item["html"]
#      18
#      19         if website.html != None:
# ---> 20             scores, embeddings = model.predict(website)
#      21
#      22     time_end_single = time.time()
#      23
#
# File ~/Documents/Uni/Project/homepage2vec/src/homepage2vec/model.py:102, in WebsiteClassifier.predict(self, website)
#     101 def predict(self, website):
# --> 102     website.features = self.get_features(website.url, website.html, website.screenshot_path)
#     103     all_features = self.concatenate_features(website)
#     104     input_features = torch.FloatTensor(all_features)
#
# File ~/Documents/Uni/Project/homepage2vec/src/homepage2vec/model.py:94, in WebsiteClassifier.get_features(self, url, html, screenshot_path)
#      92 def get_features(self, url, html, screenshot_path):
#      93     te = TextualExtractor(self.device)
# ---> 94     features = te.get_features(url, html)
#      95     if self.with_visual:
#      96         ve = VisualExtractor(self.device)
#
# File ~/Documents/Uni/Project/homepage2vec/src/homepage2vec/textual_extractor.py:48, in TextualExtractor.get_features(self, url, html)
#      45 features['f_tld'] = tld_feature
#      47 # print(html)
# ---> 48 soup = BeautifulSoup(html, 'lxml')
#      50 # metatags
#      51 metatags_feature = embed_metatags(soup, self.rep_metatags)
#
# File ~/Documents/Uni/Project/homepage2vec/.venv/lib/python3.12/site-packages/bs4/__init__.py:366, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     364     possible_builder_class = builder_registry.lookup(*features)
#     365     if possible_builder_class is None:
# --> 366         raise FeatureNotFound(
#     367             "Couldn't find a tree builder with the features you "
#     368             "requested: %s. Do you need to install a parser library?"
#     369             % ",".join(features)
#     370         )
#     371     builder_class = possible_builder_class
#     373 # At this point either we have a TreeBuilder instance in
#     374 # builder, or we have a builder_class that we can instantiate
#     375 # with the remaining **kwargs.
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
